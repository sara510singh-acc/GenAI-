# %%
pip install config

# %%
import openai
import config

openai.api_key="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"

# %%
from openai import OpenAI
client = OpenAI(api_key=openai.api_key)

# %%
response = client.audio.speech.create(
    model="tts-1",
    voice="coral",
    input='''Bonjour, si vous plait'''
)
response.stream_to_file("output.mp3")
# Out:
# /tmp/ipykernel_3141/345003318.py:6: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file("output.mp3")

# %%
audio_file = open("/content/output.mp3", "rb")
response = client.audio.transcriptions.create(
    model="whisper-1",
    file=audio_file
)

print(response.text)
# Out:
# Bonjour, s'il vous plaît.

# %%
response= client.images.generate(
    model="dall-e-2",
    prompt="A bouquet made of tulips",
    n=1,
    size="1024x1024"
)
image_url = response.data[0].url
print(f"Your image is ready at: {image_url}")
# Out:
# Your image is ready at: https://oaidalleapiprodscus.blob.core.windows.net/private/org-r6SjDhkrhdPLoKLXuvMw5wZi/user-0MKuaq7BiaC3KojIgGEkKQXj/img-EGAcVAHDYQl5K6V8WVKc66FY.png?st=2026-04-06T05%3A02%3A35Z&se=2026-04-06T07%3A02%3A35Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=475fd488-6c59-44a5-9aa9-31c4db451bea&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-04-06T06%3A02%3A35Z&ske=2026-04-07T06%3A02%3A35Z&sks=b&skv=2026-02-06&sig=iUyg/oO9ecgXj9Pm%2BXRnYkBEX26nBzxWVpnzYaBPO2M%3D
